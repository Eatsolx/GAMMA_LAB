# %% [markdown]
# In this work, you are required to implement an easy linear regression with machine learning methods based on numpy. It is better not to use the deep learning libraries such as PyTorch or Tensorflow .etc.

# %% [markdown]
# The first is the data generation. We can generate data that follows a linear distribution with the following functions.

# %%
import numpy as np
def get_data(num):
  for _ in range(num):
    x = np.random.uniform(-10.0, 10.0)
    noise = np.random.normal(0, 1)
    y = x * 2 + 1 + noise
    yield np.array([x]).astype(np.float32), np.array([y]).astype(np.float32)

x = np.array([])
y = np.array([])
for x0, y0 in get_data(1000):
  x = np.append(x, x0)
  y = np.append(y, y0)

# %% [markdown]
# The following is setting the hyperparameters, and the initialization of the learnable parameters.

# %%
learn_rate = 0.00001
epochs = 100
display_step = 10
np.random.seed(0)
w = np.random.rand()
b = np.random.rand()

# %% [markdown]
# So, you only need to write the code to train the learnable parameters w and b. We recommend you use the mean square error function.

# %%
for epoch in range(epochs):
  # Your code here
  y_hat = x * w + b
  loss = np.sqrt(np.sum((y_hat - y) ** 2)) / x.shape[0]

  grad_w = np.sum((y_hat - y) * x) / x.shape[0]
  grad_b = np.sum(y_hat - y) / x.shape[0]
  
  w -= learn_rate * grad_w
  b -= learn_rate * grad_b
  
  if (epoch + 1) % display_step == 0:
    print(f"epoch: [{epoch + 1:2d}/{epochs}]  loss: {loss:.6f}  w: {w:.4f}  b: {b:.4f}")

  # End your code
# Out:
# epoch: [10/100]  loss: 0.206067  w: 0.9003  b: 0.7178
# epoch: [20/100]  loss: 0.205380  w: 0.9040  b: 0.7178
# epoch: [30/100]  loss: 0.204695  w: 0.9078  b: 0.7179
# epoch: [40/100]  loss: 0.204013  w: 0.9115  b: 0.7179
# epoch: [50/100]  loss: 0.203333  w: 0.9152  b: 0.7179
# epoch: [60/100]  loss: 0.202656  w: 0.9189  b: 0.7180
# epoch: [70/100]  loss: 0.201981  w: 0.9226  b: 0.7180
# epoch: [80/100]  loss: 0.201308  w: 0.9263  b: 0.7180
# epoch: [90/100]  loss: 0.200638  w: 0.9300  b: 0.7181
# epoch: [100/100]  loss: 0.199969  w: 0.9336  b: 0.7181
